# %% [markdown]
# # MODELOS FINALES

# %%
import pandas as pd
import math
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense, LSTM, TimeDistributed
from tensorflow.keras.losses import mean_squared_error

# %%
completeRentalsDf = pd.read_csv('../data/completeData/rentals/completeRentalsDf_LOG1P.csv')
completeReturnsDf = pd.read_csv('../data/completeData/returns/completeReturnsDf_LOG1P.csv')

# %%
completeRentalsDf['Date'] = pd.to_datetime(completeRentalsDf['Date'])
completeRentalsDf.set_index('Date', inplace=True)
completeReturnsDf['Date'] = pd.to_datetime(completeReturnsDf['Date'])
completeReturnsDf.set_index('Date', inplace=True)

# %%
completeWeatherDf = pd.read_csv('../data/completeData/weather/completeWeatherDf.csv')

# %%
def getTrainValidationTestStationT24T48T168_ExogVariables(trainDays, validationDays, station, completeDf, completeWeatherDf):
    X_24 = np.delete(completeDf[[station]].values.reshape(-1, 24), [range(0, 6)], 0)
    X_48 = completeDf[[station]].values.reshape(-1, 24)
    X_48 = np.delete(X_48, [range(0, 5)], 0)
    X_48 = np.delete(X_48, len(X_48)-1, 0)
    X_168 = completeDf[[station]].values.reshape(-1, 24)
    X_168 = np.delete(X_168, [[len(X_168)-i for i in range(1, 7)]], 0)

    X_temp = np.delete(completeWeatherDf['temp'].values.reshape(-1, 24), [range(0, 7)], 0)
    X_humidity = np.delete(completeWeatherDf['humidity'].values.reshape(-1, 24), [range(0, 7)], 0)

    X = np.append( np.append( X_168, X_48, axis=1), X_24, axis = 1)
    X = np.delete(X, len(X)-1, 0)
    X = np.append( np.append( X_temp, X_humidity, axis=1), X, axis=1).reshape(-1,5, 24)

    X_transposed = np.empty((len(X), 24, 5))
    for i in range(0, len(X)):
        X_transposed[i] = X[i].transpose()

    X = X_transposed
    Y = np.delete(X_24, 0, 0)

    X_train, Y_train = X[0:trainDays], Y[0:trainDays]
    X_validation, Y_validation = X[trainDays:trainDays+validationDays], Y[trainDays:trainDays+validationDays]
    X_test , Y_test = X[trainDays+validationDays:X.shape[0]], Y[trainDays+validationDays:Y.shape[0]]

    return X_train, X_validation, X_test, Y_train, Y_validation, Y_test

def log1p_mse_rmse(Y_test, predictions):
    rmse = 0
    mse = 0
    for i in range(0, len(predictions)):
        mse += mean_squared_error(np.expm1(Y_test[i]), np.expm1(predictions[i]))

    mse /= len(predictions)
    rmse += math.sqrt(mse)
    print("MSE = {}, RMSE = {}".format(mse,rmse))

# %%
epochs = 10000
batch_size = 4096

# %%
stations = np.loadtxt("../data/completeData/stations/frequentedStations.txt")

# %% [markdown]
# ### MODEL SERIALIZATION

# %%
X_train, X_validation, X_test, Y_train, Y_validation, Y_test = getTrainValidationTestStationT24T48T168_ExogVariables(4000, 102, '31201', completeRentalsDf, completeWeatherDf)
def getModel(X_train):
    model = Sequential()
    model.add(LSTM(X_train.shape[1], input_shape=(X_train.shape[1], 5), return_sequences=True, name='LSTM_1'))
    model.add(TimeDistributed(Dense(16, activation="relu", name="Dense_1")))
    model.add(Dense(8, activation='relu', name='Dense_2'))
    model.add(Dense(4, activation='relu', name='Dense_3'))
    model.add(Dense(2, activation='relu', name='Dense_4'))
    model.add(Dense(1, activation='relu', name='Dense_5'))
    model.compile(loss='mean_squared_error', optimizer='adamax', metrics=['mae'])
    return model

model = getModel(X_train)
with open("../data/modelsData/LSTM_serialization.json", "w") as json_file:
    json_file.write(model.to_json())

# %% [markdown]
# ### RENTALS

# %%
for station in stations:
    station = str(int(station))
    print("Modelo alquileres estación {}".format(station))
    X_train, X_validation, X_test, Y_train, Y_validation, Y_test = getTrainValidationTestStationT24T48T168_ExogVariables(4000, 102, station, completeRentalsDf, completeWeatherDf)

    lossHistory = np.zeros((10000,), dtype=int)
    lossHistory[0], lossHistory[9999] = 0,0
    while format(lossHistory[0], '4f') == format(lossHistory[9999], '4f'):
        model = getModel(X_train)
        with tf.device('/GPU:0'):
            model.fit(X_train, Y_train.reshape(Y_train.shape[0], Y_train.shape[1], 1), batch_size=batch_size, epochs=epochs, verbose=0)
        model.save_weights("../data/modelsData/weights/rentals/rentals_"+ station +".h5")
        lossHistory = model.history.history['loss']
        print("Loss epoch nº1: {} --> Loss epoch nº10000: {}".format(format(lossHistory[0], '4f'), format(lossHistory[9999], '4f')))
# Out:
# Modelo alquileres estación 31201
# Loss epoch nº1: 2.424701 --> Loss epoch nº10000: 2.424701
# Loss epoch nº1: 1.967015 --> Loss epoch nº10000: 0.243657
# Modelo alquileres estación 31200
# Loss epoch nº1: 2.240768 --> Loss epoch nº10000: 0.260512
# Modelo alquileres estación 31101
# Loss epoch nº1: 1.945661 --> Loss epoch nº10000: 0.272801
# Modelo alquileres estación 31229
# Loss epoch nº1: 2.077129 --> Loss epoch nº10000: 0.267185
# Modelo alquileres estación 31214
# Loss epoch nº1: 1.823200 --> Loss epoch nº10000: 0.260741
# Modelo alquileres estación 31623
# Loss epoch nº1: 2.846476 --> Loss epoch nº10000: 0.269039
# Modelo alquileres estación 31203
# Loss epoch nº1: 1.448707 --> Loss epoch nº10000: 0.276690
# Modelo alquileres estación 31104
# Loss epoch nº1: 1.572671 --> Loss epoch nº10000: 1.572671
# Loss epoch nº1: 1.036292 --> Loss epoch nº10000: 0.280798
# Modelo alquileres estación 31600
# Loss epoch nº1: 1.598236 --> Loss epoch nº10000: 1.598236
# Loss epoch nº1: 1.598236 --> Loss epoch nº10000: 1.598236
# Loss epoch nº1: 1.505960 --> Loss epoch nº10000: 0.251894
# Modelo alquileres estación 31110
# Loss epoch nº1: 1.127339 --> Loss epoch nº10000: 0.237126
# Modelo alquileres estación 31613
# Loss epoch nº1: 1.807112 --> Loss epoch nº10000: 0.241664
# Modelo alquileres estación 31202
# Loss epoch nº1: 1.457578 --> Loss epoch nº10000: 1.457578
# Loss epoch nº1: 0.733813 --> Loss epoch nº10000: 0.256535
# Modelo alquileres estación 31603
# Loss epoch nº1: 1.624318 --> Loss epoch nº10000: 1.624318
# Loss epoch nº1: 1.462834 --> Loss epoch nº10000: 0.234311
# Modelo alquileres estación 31212
# Loss epoch nº1: 1.384125 --> Loss epoch nº10000: 1.384125
# Loss epoch nº1: 1.172261 --> Loss epoch nº10000: 0.247723
# Modelo alquileres estación 31241
# Loss epoch nº1: 1.876928 --> Loss epoch nº10000: 1.876928
# Loss epoch nº1: 1.876928 --> Loss epoch nº10000: 1.876928
# Loss epoch nº1: 2.809351 --> Loss epoch nº10000: 0.250655
# Modelo alquileres estación 31228
# Loss epoch nº1: 1.552038 --> Loss epoch nº10000: 0.268342
# Modelo alquileres estación 31109
# Loss epoch nº1: 1.128950 --> Loss epoch nº10000: 0.253190
# Modelo alquileres estación 31223
# Loss epoch nº1: 1.202575 --> Loss epoch nº10000: 0.251281
# Modelo alquileres estación 31602
# Loss epoch nº1: 1.237096 --> Loss epoch nº10000: 1.237096
# Loss epoch nº1: 1.237096 --> Loss epoch nº10000: 1.237096
# Loss epoch nº1: 1.115168 --> Loss epoch nº10000: 0.253644
# Modelo alquileres estación 31108
# Loss epoch nº1: 1.255866 --> Loss epoch nº10000: 0.238674
# Modelo alquileres estación 31237
# Loss epoch nº1: 1.219027 --> Loss epoch nº10000: 0.235768
# Modelo alquileres estación 31616
# Loss epoch nº1: 1.086603 --> Loss epoch nº10000: 1.086603
# Loss epoch nº1: 0.921763 --> Loss epoch nº10000: 0.238460
# Modelo alquileres estación 31232
# Loss epoch nº1: 1.053384 --> Loss epoch nº10000: 0.250735
# Modelo alquileres estación 31111
# Loss epoch nº1: 0.739248 --> Loss epoch nº10000: 0.261653
# Modelo alquileres estación 31107
# Loss epoch nº1: 1.042495 --> Loss epoch nº10000: 0.258096
# Modelo alquileres estación 31213
# Loss epoch nº1: 1.224594 --> Loss epoch nº10000: 1.224594
# Loss epoch nº1: 1.224594 --> Loss epoch nº10000: 1.224594
# Loss epoch nº1: 1.224594 --> Loss epoch nº10000: 1.224594
# Loss epoch nº1: 1.224594 --> Loss epoch nº10000: 1.224594
# Loss epoch nº1: 1.204434 --> Loss epoch nº10000: 0.236941
# Modelo alquileres estación 31624
# Loss epoch nº1: 1.419106 --> Loss epoch nº10000: 1.419106
# Loss epoch nº1: 1.419106 --> Loss epoch nº10000: 0.256736
# Modelo alquileres estación 31103
# Loss epoch nº1: 1.366016 --> Loss epoch nº10000: 0.286728
# Modelo alquileres estación 31116
# Loss epoch nº1: 0.755142 --> Loss epoch nº10000: 0.233061
# Modelo alquileres estación 31619
# Loss epoch nº1: 0.978241 --> Loss epoch nº10000: 0.238894
# Modelo alquileres estación 31221
# Loss epoch nº1: 0.939631 --> Loss epoch nº10000: 0.230133
# Modelo alquileres estación 31245
# Loss epoch nº1: 0.976792 --> Loss epoch nº10000: 0.976792
# Loss epoch nº1: 0.976792 --> Loss epoch nº10000: 0.976792
# Loss epoch nº1: 0.975307 --> Loss epoch nº10000: 0.213690
# Modelo alquileres estación 31234
# Loss epoch nº1: 1.022256 --> Loss epoch nº10000: 1.022256
# Loss epoch nº1: 1.022256 --> Loss epoch nº10000: 1.022256
# Loss epoch nº1: 1.022221 --> Loss epoch nº10000: 0.209350
# Modelo alquileres estación 31246
# Loss epoch nº1: 0.856596 --> Loss epoch nº10000: 0.215699
# Modelo alquileres estación 31102
# Loss epoch nº1: 1.049741 --> Loss epoch nº10000: 1.049741
# Loss epoch nº1: 1.049741 --> Loss epoch nº10000: 1.049741
# Loss epoch nº1: 0.971681 --> Loss epoch nº10000: 0.268501
# Modelo alquileres estación 31618
# Loss epoch nº1: 0.892136 --> Loss epoch nº10000: 0.241146
# Modelo alquileres estación 31266
# Loss epoch nº1: 1.169077 --> Loss epoch nº10000: 0.199282
# Modelo alquileres estación 31503
# Loss epoch nº1: 0.869699 --> Loss epoch nº10000: 0.869699
# Loss epoch nº1: 0.719836 --> Loss epoch nº10000: 0.234181
# Modelo alquileres estación 31230
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.214900 --> Loss epoch nº10000: 1.214900
# Loss epoch nº1: 1.203804 --> Loss epoch nº10000: 0.229632
# Modelo alquileres estación 31611
# Loss epoch nº1: 0.829927 --> Loss epoch nº10000: 0.239418
# Modelo alquileres estación 31610
# Loss epoch nº1: 0.954682 --> Loss epoch nº10000: 0.954682
# Loss epoch nº1: 0.954682 --> Loss epoch nº10000: 0.954682
# Loss epoch nº1: 2.985710 --> Loss epoch nº10000: 0.226698
# Modelo alquileres estación 31257
# Loss epoch nº1: 1.101324 --> Loss epoch nº10000: 1.101324
# Loss epoch nº1: 1.101324 --> Loss epoch nº10000: 1.101325
# Modelo alquileres estación 31205
# Loss epoch nº1: 0.952461 --> Loss epoch nº10000: 0.244394
# Modelo alquileres estación 31506
# Loss epoch nº1: 0.625559 --> Loss epoch nº10000: 0.217919
# Modelo alquileres estación 31222
# Loss epoch nº1: 1.277153 --> Loss epoch nº10000: 1.277153
# Loss epoch nº1: 1.164713 --> Loss epoch nº10000: 0.272431
# Modelo alquileres estación 31604
# Loss epoch nº1: 0.651479 --> Loss epoch nº10000: 0.218287
# Modelo alquileres estación 31615
# Loss epoch nº1: 0.903944 --> Loss epoch nº10000: 0.903944
# Loss epoch nº1: 0.903944 --> Loss epoch nº10000: 0.903944
# Loss epoch nº1: 0.903649 --> Loss epoch nº10000: 0.214808
# Modelo alquileres estación 31628
# Loss epoch nº1: 0.946720 --> Loss epoch nº10000: 0.946720
# Loss epoch nº1: 0.892407 --> Loss epoch nº10000: 0.211254
# Modelo alquileres estación 31225
# Loss epoch nº1: 0.927604 --> Loss epoch nº10000: 0.242888
# Modelo alquileres estación 31239
# Loss epoch nº1: 1.052524 --> Loss epoch nº10000: 1.052524
# Loss epoch nº1: 1.052524 --> Loss epoch nº10000: 1.052524
# Loss epoch nº1: 1.029291 --> Loss epoch nº10000: 0.207985
# Modelo alquileres estación 31400
# Loss epoch nº1: 0.767946 --> Loss epoch nº10000: 0.227787
# Modelo alquileres estación 31265
# Loss epoch nº1: 1.098854 --> Loss epoch nº10000: 0.191003
# Modelo alquileres estación 31247
# Loss epoch nº1: 1.913671 --> Loss epoch nº10000: 0.296809
# Modelo alquileres estación 31620
# Loss epoch nº1: 0.893735 --> Loss epoch nº10000: 0.893735
# Loss epoch nº1: 0.891035 --> Loss epoch nº10000: 0.239351
# Modelo alquileres estación 31605
# Loss epoch nº1: 0.521643 --> Loss epoch nº10000: 0.217723
# Modelo alquileres estación 31204
# Loss epoch nº1: 0.610484 --> Loss epoch nº10000: 0.231616
# Modelo alquileres estación 31251
# Loss epoch nº1: 0.817412 --> Loss epoch nº10000: 0.817412
# Loss epoch nº1: 0.817412 --> Loss epoch nº10000: 0.817412
# Loss epoch nº1: 0.817412 --> Loss epoch nº10000: 0.817412
# Loss epoch nº1: 0.798506 --> Loss epoch nº10000: 0.200230
# Modelo alquileres estación 31233
# Loss epoch nº1: 0.959271 --> Loss epoch nº10000: 0.959271
# Loss epoch nº1: 0.959271 --> Loss epoch nº10000: 0.959271
# Loss epoch nº1: 0.959225 --> Loss epoch nº10000: 0.232982
# Modelo alquileres estación 31258
# Loss epoch nº1: 1.469930 --> Loss epoch nº10000: 0.310922
# Modelo alquileres estación 31238
# Loss epoch nº1: 0.972657 --> Loss epoch nº10000: 0.972657
# Loss epoch nº1: 0.770725 --> Loss epoch nº10000: 0.249076
# Modelo alquileres estación 31267
# Loss epoch nº1: 1.001602 --> Loss epoch nº10000: 1.001602
# Loss epoch nº1: 1.000418 --> Loss epoch nº10000: 0.191770
# Modelo alquileres estación 31105
# Loss epoch nº1: 0.954868 --> Loss epoch nº10000: 0.954868
# Loss epoch nº1: 0.954868 --> Loss epoch nº10000: 0.954868
# Loss epoch nº1: 0.954868 --> Loss epoch nº10000: 0.954868
# Loss epoch nº1: 0.954868 --> Loss epoch nº10000: 0.954868
# Loss epoch nº1: 0.952857 --> Loss epoch nº10000: 0.249231
# Modelo alquileres estación 31244
# Loss epoch nº1: 0.886097 --> Loss epoch nº10000: 0.198554
# Modelo alquileres estación 31627
# Loss epoch nº1: 0.903390 --> Loss epoch nº10000: 0.187432
# Modelo alquileres estación 31114
# Loss epoch nº1: 0.942130 --> Loss epoch nº10000: 0.942130
# Loss epoch nº1: 0.942130 --> Loss epoch nº10000: 0.942130
# Loss epoch nº1: 0.942130 --> Loss epoch nº10000: 0.942130
# Loss epoch nº1: 0.941908 --> Loss epoch nº10000: 0.221886
# Modelo alquileres estación 31606
# Loss epoch nº1: 0.616479 --> Loss epoch nº10000: 0.616479
# Loss epoch nº1: 0.616477 --> Loss epoch nº10000: 0.206223
# Modelo alquileres estación 31236
# Loss epoch nº1: 0.786181 --> Loss epoch nº10000: 0.217837
# Modelo alquileres estación 31014
# Loss epoch nº1: 0.741931 --> Loss epoch nº10000: 0.741930
# Modelo alquileres estación 31215
# Loss epoch nº1: 0.792663 --> Loss epoch nº10000: 0.239528
# Modelo alquileres estación 31227
# Loss epoch nº1: 0.827015 --> Loss epoch nº10000: 0.227907
# Modelo alquileres estación 31218
# Loss epoch nº1: 1.009593 --> Loss epoch nº10000: 0.240359
# Modelo alquileres estación 31401
# Loss epoch nº1: 0.601944 --> Loss epoch nº10000: 0.217583
# Modelo alquileres estación 31622
# Loss epoch nº1: 0.699892 --> Loss epoch nº10000: 0.206129
# Modelo alquileres estación 31505
# Loss epoch nº1: 0.582363 --> Loss epoch nº10000: 0.582363
# Loss epoch nº1: 0.560660 --> Loss epoch nº10000: 0.186752
# Modelo alquileres estación 31224
# Loss epoch nº1: 0.671909 --> Loss epoch nº10000: 0.199626
# Modelo alquileres estación 31248
# Loss epoch nº1: 1.557176 --> Loss epoch nº10000: 0.267300
# Modelo alquileres estación 31113
# Loss epoch nº1: 0.815699 --> Loss epoch nº10000: 0.250801
# Modelo alquileres estación 31249
# Loss epoch nº1: 1.486589 --> Loss epoch nº10000: 0.268475
# Modelo alquileres estación 31263
# Loss epoch nº1: 0.855531 --> Loss epoch nº10000: 0.855531
# Loss epoch nº1: 0.855531 --> Loss epoch nº10000: 0.855531
# Loss epoch nº1: 0.850723 --> Loss epoch nº10000: 0.188479
# Modelo alquileres estación 31119
# Loss epoch nº1: 0.784974 --> Loss epoch nº10000: 0.184288
# Modelo alquileres estación 31268
# Loss epoch nº1: 0.683088 --> Loss epoch nº10000: 0.197295
# Modelo alquileres estación 31612
# Loss epoch nº1: 0.766113 --> Loss epoch nº10000: 0.190810
# Modelo alquileres estación 31243
# Loss epoch nº1: 1.008619 --> Loss epoch nº10000: 0.231853
# Modelo alquileres estación 31625
# Loss epoch nº1: 0.528789 --> Loss epoch nº10000: 0.176349
# Modelo alquileres estación 31231
# Loss epoch nº1: 0.933958 --> Loss epoch nº10000: 0.232162
# Modelo alquileres estación 31216
# Loss epoch nº1: 0.741487 --> Loss epoch nº10000: 0.240464
# Modelo alquileres estación 31255
# Loss epoch nº1: 0.664467 --> Loss epoch nº10000: 0.173632
# Modelo alquileres estación 31208
# Loss epoch nº1: 0.576030 --> Loss epoch nº10000: 0.576030
# Loss epoch nº1: 0.573166 --> Loss epoch nº10000: 0.205925
# Modelo alquileres estación 31219
# Loss epoch nº1: 0.977784 --> Loss epoch nº10000: 0.228029
# Modelo alquileres estación 31121
# Loss epoch nº1: 0.754077 --> Loss epoch nº10000: 0.167029
# Modelo alquileres estación 31117
# Loss epoch nº1: 0.728410 --> Loss epoch nº10000: 0.200561
# Modelo alquileres estación 31614
# Loss epoch nº1: 0.493148 --> Loss epoch nº10000: 0.190882
# Modelo alquileres estación 31609
# Loss epoch nº1: 0.557152 --> Loss epoch nº10000: 0.557152
# Loss epoch nº1: 0.391650 --> Loss epoch nº10000: 0.212599
# Modelo alquileres estación 31115
# Loss epoch nº1: 0.604396 --> Loss epoch nº10000: 0.197382
# Modelo alquileres estación 31242
# Loss epoch nº1: 0.792156 --> Loss epoch nº10000: 0.216655
# Modelo alquileres estación 31256
# Loss epoch nº1: 0.707445 --> Loss epoch nº10000: 0.202954
# Modelo alquileres estación 31269
# Loss epoch nº1: 0.624998 --> Loss epoch nº10000: 0.187713
# Modelo alquileres estación 31275
# Loss epoch nº1: 0.660719 --> Loss epoch nº10000: 0.158545
# Modelo alquileres estación 31305
# Loss epoch nº1: 0.444028 --> Loss epoch nº10000: 0.444028
# Loss epoch nº1: 0.412301 --> Loss epoch nº10000: 0.183861
# Modelo alquileres estación 31278
# Loss epoch nº1: 0.719723 --> Loss epoch nº10000: 0.719723
# Loss epoch nº1: 0.719723 --> Loss epoch nº10000: 0.719723
# Loss epoch nº1: 0.494660 --> Loss epoch nº10000: 0.145878

# %% [markdown]
# ### RETURNS

# %%
for station in stations:
    station = str(int(station))
    print("Modelo devoluciones estación {}".format(station))
    X_train, X_validation, X_test, Y_train, Y_validation, Y_test = getTrainValidationTestStationT24T48T168_ExogVariables(4000, 102, station, completeReturnsDf, completeWeatherDf)

    lossHistory = np.zeros((10000,), dtype=int)
    lossHistory[0], lossHistory[9999] = 0,0
    while format(lossHistory[0], '4f') == format(lossHistory[9999], '4f'):
        model = getModel(X_train)
        with tf.device('/GPU:0'):
            model.fit(X_train, Y_train.reshape(Y_train.shape[0], Y_train.shape[1], 1), batch_size=batch_size, epochs=epochs, verbose=0)
        model.save_weights("../data/modelsData/weights/returns/returns_"+ station +".h5")
        lossHistory = model.history.history['loss']
        print("Loss epoch nº1: {} --> Loss epoch nº10000: {}".format(format(lossHistory[0], '4f'), format(lossHistory[9999], '4f')))
# Out:
# Modelo devoluciones estación 31201
# Loss epoch nº1: 2.609834 --> Loss epoch nº10000: 0.230541
# Modelo devoluciones estación 31200
# Loss epoch nº1: 3.023365 --> Loss epoch nº10000: 0.241363
# Modelo devoluciones estación 31101
# Loss epoch nº1: 2.082462 --> Loss epoch nº10000: 2.082462
# Loss epoch nº1: 2.082462 --> Loss epoch nº10000: 2.082462
# Loss epoch nº1: 2.082462 --> Loss epoch nº10000: 2.082462
# Loss epoch nº1: 2.047203 --> Loss epoch nº10000: 0.250589
# Modelo devoluciones estación 31229
# Loss epoch nº1: 1.918375 --> Loss epoch nº10000: 0.235093
# Modelo devoluciones estación 31214
# Loss epoch nº1: 1.864711 --> Loss epoch nº10000: 1.864711
# Loss epoch nº1: 1.863884 --> Loss epoch nº10000: 0.236491
# Modelo devoluciones estación 31623
# Loss epoch nº1: 3.027580 --> Loss epoch nº10000: 3.027579
# Modelo devoluciones estación 31203
# Loss epoch nº1: 1.677022 --> Loss epoch nº10000: 0.249074
# Modelo devoluciones estación 31104
# Loss epoch nº1: 1.329592 --> Loss epoch nº10000: 1.329592
# Loss epoch nº1: 1.329592 --> Loss epoch nº10000: 1.329592
# Loss epoch nº1: 1.299101 --> Loss epoch nº10000: 0.239368
# Modelo devoluciones estación 31600
# Loss epoch nº1: 1.645021 --> Loss epoch nº10000: 0.244588
# Modelo devoluciones estación 31110
# Loss epoch nº1: 1.136329 --> Loss epoch nº10000: 0.236154
# Modelo devoluciones estación 31613
# Loss epoch nº1: 1.697258 --> Loss epoch nº10000: 0.225565
# Modelo devoluciones estación 31202
# Loss epoch nº1: 1.556465 --> Loss epoch nº10000: 0.230990
# Modelo devoluciones estación 31603
# Loss epoch nº1: 0.745924 --> Loss epoch nº10000: 0.250168
# Modelo devoluciones estación 31212
# Loss epoch nº1: 1.503017 --> Loss epoch nº10000: 1.503017
# Loss epoch nº1: 1.503017 --> Loss epoch nº10000: 1.503017
# Loss epoch nº1: 1.488563 --> Loss epoch nº10000: 0.249136
# Modelo devoluciones estación 31241
# Loss epoch nº1: 1.578057 --> Loss epoch nº10000: 0.232852
# Modelo devoluciones estación 31228
# Loss epoch nº1: 1.717773 --> Loss epoch nº10000: 0.249256
# Modelo devoluciones estación 31109
# Loss epoch nº1: 1.202224 --> Loss epoch nº10000: 1.202224
# Loss epoch nº1: 1.202224 --> Loss epoch nº10000: 1.202224
# Loss epoch nº1: 1.202203 --> Loss epoch nº10000: 0.234647
# Modelo devoluciones estación 31223
# Loss epoch nº1: 1.156943 --> Loss epoch nº10000: 1.156943
# Loss epoch nº1: 1.126428 --> Loss epoch nº10000: 0.242663
# Modelo devoluciones estación 31602
# Loss epoch nº1: 0.982373 --> Loss epoch nº10000: 0.982373
# Loss epoch nº1: 0.928384 --> Loss epoch nº10000: 0.223749
# Modelo devoluciones estación 31108
# Loss epoch nº1: 1.389243 --> Loss epoch nº10000: 1.389243
# Loss epoch nº1: 1.232064 --> Loss epoch nº10000: 0.239398
# Modelo devoluciones estación 31237
# Loss epoch nº1: 1.285156 --> Loss epoch nº10000: 1.285156
# Loss epoch nº1: 1.105720 --> Loss epoch nº10000: 0.237186
# Modelo devoluciones estación 31616
# Loss epoch nº1: 1.140469 --> Loss epoch nº10000: 0.229382
# Modelo devoluciones estación 31232
# Loss epoch nº1: 1.336784 --> Loss epoch nº10000: 0.237587
# Modelo devoluciones estación 31111
# Loss epoch nº1: 1.018988 --> Loss epoch nº10000: 1.018988
# Loss epoch nº1: 0.599013 --> Loss epoch nº10000: 0.228867
# Modelo devoluciones estación 31107
# Loss epoch nº1: 0.832562 --> Loss epoch nº10000: 0.832562
# Loss epoch nº1: 0.832562 --> Loss epoch nº10000: 0.832562
# Loss epoch nº1: 0.832355 --> Loss epoch nº10000: 0.215564
# Modelo devoluciones estación 31213
# Loss epoch nº1: 1.365243 --> Loss epoch nº10000: 1.365243
# Loss epoch nº1: 1.365243 --> Loss epoch nº10000: 1.365243
# Loss epoch nº1: 1.365240 --> Loss epoch nº10000: 0.233203
# Modelo devoluciones estación 31624
# Loss epoch nº1: 1.468577 --> Loss epoch nº10000: 0.789529
# Modelo devoluciones estación 31103
# Loss epoch nº1: 0.722917 --> Loss epoch nº10000: 0.722917
# Loss epoch nº1: 0.722917 --> Loss epoch nº10000: 0.210815
# Modelo devoluciones estación 31116
# Loss epoch nº1: 1.057119 --> Loss epoch nº10000: 1.057119
# Loss epoch nº1: 1.046714 --> Loss epoch nº10000: 0.213241
# Modelo devoluciones estación 31619
# Loss epoch nº1: 0.903526 --> Loss epoch nº10000: 0.218560
# Modelo devoluciones estación 31221
# Loss epoch nº1: 1.092087 --> Loss epoch nº10000: 0.237502
# Modelo devoluciones estación 31245
# Loss epoch nº1: 0.950276 --> Loss epoch nº10000: 0.207179
# Modelo devoluciones estación 31234
# Loss epoch nº1: 1.098606 --> Loss epoch nº10000: 1.098606
# Loss epoch nº1: 1.098606 --> Loss epoch nº10000: 1.098606
# Loss epoch nº1: 1.071899 --> Loss epoch nº10000: 0.211310
# Modelo devoluciones estación 31246
# Loss epoch nº1: 1.056830 --> Loss epoch nº10000: 0.218547
# Modelo devoluciones estación 31102
# Loss epoch nº1: 0.782979 --> Loss epoch nº10000: 0.782979
# Loss epoch nº1: 0.492632 --> Loss epoch nº10000: 0.206694
# Modelo devoluciones estación 31618
# Loss epoch nº1: 0.915648 --> Loss epoch nº10000: 0.915648
# Loss epoch nº1: 0.913606 --> Loss epoch nº10000: 0.231801
# Modelo devoluciones estación 31266
# Loss epoch nº1: 1.100140 --> Loss epoch nº10000: 1.100140
# Loss epoch nº1: 0.985005 --> Loss epoch nº10000: 0.186896
# Modelo devoluciones estación 31503
# Loss epoch nº1: 0.855810 --> Loss epoch nº10000: 0.855810
# Loss epoch nº1: 0.855810 --> Loss epoch nº10000: 0.855810
# Loss epoch nº1: 0.855810 --> Loss epoch nº10000: 0.855810
# Loss epoch nº1: 0.855810 --> Loss epoch nº10000: 0.855810
# Loss epoch nº1: 0.693828 --> Loss epoch nº10000: 0.226153
# Modelo devoluciones estación 31230
# Loss epoch nº1: 1.391006 --> Loss epoch nº10000: 0.234909
# Modelo devoluciones estación 31611
# Loss epoch nº1: 0.911880 --> Loss epoch nº10000: 0.911880
# Loss epoch nº1: 0.911880 --> Loss epoch nº10000: 0.911880
# Loss epoch nº1: 0.594360 --> Loss epoch nº10000: 0.222052
# Modelo devoluciones estación 31610
# Loss epoch nº1: 0.902215 --> Loss epoch nº10000: 0.224683
# Modelo devoluciones estación 31257
# Loss epoch nº1: 0.698954 --> Loss epoch nº10000: 0.209405
# Modelo devoluciones estación 31205
# Loss epoch nº1: 1.127257 --> Loss epoch nº10000: 0.254750
# Modelo devoluciones estación 31506
# Loss epoch nº1: 0.626805 --> Loss epoch nº10000: 0.197799
# Modelo devoluciones estación 31222
# Loss epoch nº1: 1.361853 --> Loss epoch nº10000: 1.361853
# Loss epoch nº1: 1.361853 --> Loss epoch nº10000: 1.361853
# Loss epoch nº1: 1.223669 --> Loss epoch nº10000: 0.289526
# Modelo devoluciones estación 31604
# Loss epoch nº1: 0.543916 --> Loss epoch nº10000: 0.224367
# Modelo devoluciones estación 31615
# Loss epoch nº1: 1.008834 --> Loss epoch nº10000: 1.008834
# Loss epoch nº1: 1.008834 --> Loss epoch nº10000: 1.008834
# Loss epoch nº1: 1.002162 --> Loss epoch nº10000: 0.210369
# Modelo devoluciones estación 31628
# Loss epoch nº1: 1.027029 --> Loss epoch nº10000: 1.027029
# Loss epoch nº1: 1.026496 --> Loss epoch nº10000: 0.209899
# Modelo devoluciones estación 31225
# Loss epoch nº1: 0.798174 --> Loss epoch nº10000: 0.257779
# Modelo devoluciones estación 31239
# Loss epoch nº1: 1.139261 --> Loss epoch nº10000: 1.139261
# Loss epoch nº1: 1.032851 --> Loss epoch nº10000: 0.215174
# Modelo devoluciones estación 31400
# Loss epoch nº1: 0.569063 --> Loss epoch nº10000: 0.195953
# Modelo devoluciones estación 31265
# Loss epoch nº1: 1.117021 --> Loss epoch nº10000: 1.117021
# Loss epoch nº1: 1.075731 --> Loss epoch nº10000: 0.183744
# Modelo devoluciones estación 31247
# Loss epoch nº1: 2.166965 --> Loss epoch nº10000: 0.293241
# Modelo devoluciones estación 31620
# Loss epoch nº1: 0.527215 --> Loss epoch nº10000: 0.252782
# Modelo devoluciones estación 31605
# Loss epoch nº1: 0.685657 --> Loss epoch nº10000: 0.209579
# Modelo devoluciones estación 31204
# Loss epoch nº1: 0.776695 --> Loss epoch nº10000: 0.237734
# Modelo devoluciones estación 31251
# Loss epoch nº1: 0.787429 --> Loss epoch nº10000: 0.787429
# Loss epoch nº1: 0.787429 --> Loss epoch nº10000: 0.787429
# Loss epoch nº1: 0.787429 --> Loss epoch nº10000: 0.787429
# Loss epoch nº1: 0.773641 --> Loss epoch nº10000: 0.195491
# Modelo devoluciones estación 31233
# Loss epoch nº1: 1.151436 --> Loss epoch nº10000: 1.151436
# Loss epoch nº1: 1.150123 --> Loss epoch nº10000: 0.239483
# Modelo devoluciones estación 31258
# Loss epoch nº1: 2.192403 --> Loss epoch nº10000: 0.312081
# Modelo devoluciones estación 31238
# Loss epoch nº1: 1.047049 --> Loss epoch nº10000: 0.255372
# Modelo devoluciones estación 31267
# Loss epoch nº1: 1.001414 --> Loss epoch nº10000: 1.001414
# Loss epoch nº1: 1.001414 --> Loss epoch nº10000: 1.001414
# Loss epoch nº1: 1.001414 --> Loss epoch nº10000: 1.001414
# Loss epoch nº1: 1.001408 --> Loss epoch nº10000: 0.178840
# Modelo devoluciones estación 31105
# Loss epoch nº1: 0.613165 --> Loss epoch nº10000: 0.613165
# Loss epoch nº1: 0.562985 --> Loss epoch nº10000: 0.184261
# Modelo devoluciones estación 31244
# Loss epoch nº1: 0.992661 --> Loss epoch nº10000: 0.992661
# Loss epoch nº1: 0.992660 --> Loss epoch nº10000: 0.992660
# Loss epoch nº1: 0.992661 --> Loss epoch nº10000: 0.992661
# Loss epoch nº1: 0.874550 --> Loss epoch nº10000: 0.228047
# Modelo devoluciones estación 31627
# Loss epoch nº1: 0.937344 --> Loss epoch nº10000: 0.201892
# Modelo devoluciones estación 31114
# Loss epoch nº1: 0.806075 --> Loss epoch nº10000: 0.185427
# Modelo devoluciones estación 31606
# Loss epoch nº1: 0.571892 --> Loss epoch nº10000: 0.192281
# Modelo devoluciones estación 31236
# Loss epoch nº1: 0.770735 --> Loss epoch nº10000: 0.219676
# Modelo devoluciones estación 31014
# Loss epoch nº1: 0.958225 --> Loss epoch nº10000: 0.225425
# Modelo devoluciones estación 31215
# Loss epoch nº1: 1.276724 --> Loss epoch nº10000: 1.276724
# Loss epoch nº1: 1.138416 --> Loss epoch nº10000: 0.259324
# Modelo devoluciones estación 31227
# Loss epoch nº1: 1.026143 --> Loss epoch nº10000: 0.232387
# Modelo devoluciones estación 31218
# Loss epoch nº1: 0.721992 --> Loss epoch nº10000: 0.240448
# Modelo devoluciones estación 31401
# Loss epoch nº1: 0.469010 --> Loss epoch nº10000: 0.174665
# Modelo devoluciones estación 31622
# Loss epoch nº1: 0.764994 --> Loss epoch nº10000: 0.764994
# Loss epoch nº1: 0.764993 --> Loss epoch nº10000: 0.193020
# Modelo devoluciones estación 31505
# Loss epoch nº1: 0.536977 --> Loss epoch nº10000: 0.536977
# Loss epoch nº1: 0.514409 --> Loss epoch nº10000: 0.184160
# Modelo devoluciones estación 31224
# Loss epoch nº1: 0.614914 --> Loss epoch nº10000: 0.198762
# Modelo devoluciones estación 31248
# Loss epoch nº1: 1.315968 --> Loss epoch nº10000: 0.271883
# Modelo devoluciones estación 31113
# Loss epoch nº1: 0.506576 --> Loss epoch nº10000: 0.166936
# Modelo devoluciones estación 31249
# Loss epoch nº1: 1.516451 --> Loss epoch nº10000: 1.516451
# Loss epoch nº1: 1.516450 --> Loss epoch nº10000: 1.516450
# Loss epoch nº1: 1.516451 --> Loss epoch nº10000: 1.516451
# Loss epoch nº1: 1.263414 --> Loss epoch nº10000: 0.277514
# Modelo devoluciones estación 31263
# Loss epoch nº1: 0.838800 --> Loss epoch nº10000: 0.192986
# Modelo devoluciones estación 31119
# Loss epoch nº1: 0.710620 --> Loss epoch nº10000: 0.710620
# Loss epoch nº1: 0.710620 --> Loss epoch nº10000: 0.710620
# Loss epoch nº1: 0.710620 --> Loss epoch nº10000: 0.710620
# Loss epoch nº1: 0.693097 --> Loss epoch nº10000: 0.165895
# Modelo devoluciones estación 31268
# Loss epoch nº1: 0.890059 --> Loss epoch nº10000: 0.177982
# Modelo devoluciones estación 31612
# Loss epoch nº1: 0.477314 --> Loss epoch nº10000: 0.182828
# Modelo devoluciones estación 31243
# Loss epoch nº1: 1.279072 --> Loss epoch nº10000: 0.247513
# Modelo devoluciones estación 31625
# Loss epoch nº1: 0.585972 --> Loss epoch nº10000: 0.585972
# Loss epoch nº1: 0.585972 --> Loss epoch nº10000: 0.585972
# Loss epoch nº1: 0.584095 --> Loss epoch nº10000: 0.177534
# Modelo devoluciones estación 31231
# Loss epoch nº1: 1.144845 --> Loss epoch nº10000: 1.144845
# Loss epoch nº1: 1.140919 --> Loss epoch nº10000: 0.258825
# Modelo devoluciones estación 31216
# Loss epoch nº1: 0.794726 --> Loss epoch nº10000: 0.794726
# Loss epoch nº1: 0.712084 --> Loss epoch nº10000: 0.233372
# Modelo devoluciones estación 31255
# Loss epoch nº1: 0.723904 --> Loss epoch nº10000: 0.182760
# Modelo devoluciones estación 31208
# Loss epoch nº1: 0.725840 --> Loss epoch nº10000: 0.227912
# Modelo devoluciones estación 31219
# Loss epoch nº1: 1.116686 --> Loss epoch nº10000: 0.263608
# Modelo devoluciones estación 31121
# Loss epoch nº1: 0.629716 --> Loss epoch nº10000: 0.160249
# Modelo devoluciones estación 31117
# Loss epoch nº1: 0.319486 --> Loss epoch nº10000: 0.149399
# Modelo devoluciones estación 31614
# Loss epoch nº1: 0.642353 --> Loss epoch nº10000: 0.642353
# Loss epoch nº1: 0.642353 --> Loss epoch nº10000: 0.642353
# Loss epoch nº1: 0.473159 --> Loss epoch nº10000: 0.187196
# Modelo devoluciones estación 31609
# Loss epoch nº1: 0.679576 --> Loss epoch nº10000: 0.679576
# Loss epoch nº1: 0.679576 --> Loss epoch nº10000: 0.679576
# Loss epoch nº1: 0.598961 --> Loss epoch nº10000: 0.219408
# Modelo devoluciones estación 31115
# Loss epoch nº1: 0.406477 --> Loss epoch nº10000: 0.406477
# Loss epoch nº1: 0.329899 --> Loss epoch nº10000: 0.151055
# Modelo devoluciones estación 31242
# Loss epoch nº1: 0.669526 --> Loss epoch nº10000: 0.214749
# Modelo devoluciones estación 31256
# Loss epoch nº1: 0.770324 --> Loss epoch nº10000: 0.220517
# Modelo devoluciones estación 31269
# Loss epoch nº1: 0.710826 --> Loss epoch nº10000: 0.710826
# Loss epoch nº1: 0.710571 --> Loss epoch nº10000: 0.182734
# Modelo devoluciones estación 31275
# Loss epoch nº1: 0.711392 --> Loss epoch nº10000: 0.711392
# Loss epoch nº1: 0.711392 --> Loss epoch nº10000: 0.711392
# Loss epoch nº1: 0.711283 --> Loss epoch nº10000: 0.165518
# Modelo devoluciones estación 31305
# Loss epoch nº1: 0.393000 --> Loss epoch nº10000: 0.393000
# Loss epoch nº1: 0.308046 --> Loss epoch nº10000: 0.165887
# Modelo devoluciones estación 31278
# Loss epoch nº1: 0.721426 --> Loss epoch nº10000: 0.141824
